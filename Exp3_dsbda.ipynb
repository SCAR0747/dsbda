# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[222], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[221], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df = pd.read_csv(r"C:\Users\Amaan\Desktop\heart.csv", sep=',')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  active
# 0   0     1       1       0
# 1   0     2       1       0
# 2   0     2       1       0
# 3   0     2       1       0
# 4   0     2       1       0

# %%
df.shape
# Out:
# (49, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       49 non-null     int64
#  1   sex       49 non-null     int64
#  2   cp        49 non-null     int64
#  3   trestbps  49 non-null     int64
#  4   chol      49 non-null     int64
#  5   fbs       49 non-null     int64
#  6   restecg   49 non-null     int64
#  7   thalach   49 non-null     int64
#  8   exang     49 non-null     int64
#  9   oldpeak   49 non-null     float64
#  10  slope     49 non-null     int64
#  11  ca        49 non-null     int64
#  12  thal      49 non-null     int64
#  13  target    49 non-null     int64
#  14  active    49 non-null     int64
# dtypes: float64(1), int64(14)
# memory usage: 5.9 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# active      0
# dtype: int64

# %%
df.count() #It results in a number of non null values in each column.
# Out:
# age         49
# sex         49
# cp          49
# trestbps    49
# chol        49
# fbs         49
# restecg     49
# thalach     49
# exang       49
# oldpeak     49
# slope       49
# ca          49
# thal        49
# target      49
# active      49
# dtype: int64

# %%
df.describe()
# Out:
#              age        sex         cp    trestbps        chol        fbs  \
# count  49.000000  49.000000  49.000000   49.000000   49.000000  49.000000
# mean   52.959184   0.612245   1.571429  134.877551  248.510204   0.163265
# std     8.531704   0.492287   0.957427   14.549674   53.050731   0.373438
# min    37.000000   0.000000   0.000000  104.000000  168.000000   0.000000
# 25%    46.000000   0.000000   1.000000  125.000000  212.000000   0.000000
# 50%    53.000000   1.000000   2.000000  135.000000  236.000000   0.000000
# 75%    58.000000   1.000000   2.000000  142.000000  273.000000   0.000000
# max    71.000000   1.000000   3.000000  172.000000  417.000000   1.000000
#
#          restecg     thalach      exang    oldpeak      slope         ca  \
# count  49.000000   49.000000  49.000000  49.000000  49.000000  49.000000
# mean    0.571429  158.591837   0.163265   0.914286   1.571429   0.183673
# std     0.500000   17.775121   0.373438   0.832666   0.707107   0.486204
# ...

# %%
#cleaning dataset
df=df.drop(['slope','cp','ca',], axis = 1) 
#dropping columns that aren't required

# %%
df.shape
# Out:
# (49, 12)

# %%
df.describe()
# Out:
#              age    trestbps        chol    restecg     thalach    oldpeak  \
# count  49.000000   49.000000   49.000000  49.000000   49.000000  49.000000
# mean   52.959184  134.877551  248.510204   0.571429  158.591837   0.914286
# std     8.531704   14.549674   53.050731   0.500000   17.775121   0.832666
# min    37.000000  104.000000  168.000000   0.000000  114.000000   0.000000
# 25%    46.000000  125.000000  212.000000   0.000000  148.000000   0.200000
# 50%    53.000000  135.000000  236.000000   1.000000  160.000000   0.800000
# 75%    58.000000  142.000000  273.000000   1.000000  172.000000   1.400000
# max    71.000000  172.000000  417.000000   1.000000  188.000000   3.500000
#
#             thal
# count  49.000000
# mean    2.040816
# std     0.498296
# min     0.000000
# 25%     2.000000
# 50%     2.000000
# 75%     2.000000
# max     3.000000

# %%
df['target'] = df.target.replace({1: "Yes", 0: "No"})

# %%
df.target.head()
# Out:
# 0    Yes
# 1    Yes
# 2    Yes
# 3    Yes
# 4    Yes
# Name: target, dtype: object

# %%
df['sex'] = df['sex'].replace({1: "Male", 0: "Female"})

# %%
df.head()
# Out:
#    age     sex  trestbps  chol    fbs  restecg  thalach exang  oldpeak  thal  \
# 0   63    Male       145   233   True        0      150    No      2.3     1
# 1   37    Male       130   250  False        1      187    No      3.5     2
# 2   41  Female       130   204  False        0      172    No      1.4     2
# 3   56    Male       120   236  False        1      178    No      0.8     2
# 4   57  Female       120   354  False        1      163   Yes      0.6     2
#
#   target      active
# 0    Yes  No_Disease
# 1    Yes  No_Disease
# 2    Yes  No_Disease
# 3    Yes  No_Disease
# 4    Yes  No_Disease

# %%
df['active'] = df.active.replace({1: "Disease", 0: "No_Disease"})

# %%
df.head()
# Out:
#    age     sex  trestbps  chol    fbs  restecg  thalach exang  oldpeak  thal  \
# 0   63    Male       145   233   True        0      150    No      2.3     1
# 1   37    Male       130   250  False        1      187    No      3.5     2
# 2   41  Female       130   204  False        0      172    No      1.4     2
# 3   56    Male       120   236  False        1      178    No      0.8     2
# 4   57  Female       120   354  False        1      163   Yes      0.6     2
#
#   target      active
# 0    Yes  No_Disease
# 1    Yes  No_Disease
# 2    Yes  No_Disease
# 3    Yes  No_Disease
# 4    Yes  No_Disease

# %%
df['fbs'] = df['fbs'].replace({1: "True", 0: "False"})

# %%
df.head()
# Out:
#    age     sex  trestbps  chol    fbs  restecg  thalach exang  oldpeak  thal  \
# 0   63    Male       145   233   True        0      150    No      2.3     1
# 1   37    Male       130   250  False        1      187    No      3.5     2
# 2   41  Female       130   204  False        0      172    No      1.4     2
# 3   56    Male       120   236  False        1      178    No      0.8     2
# 4   57  Female       120   354  False        1      163   Yes      0.6     2
#
#   target      active
# 0    Yes  No_Disease
# 1    Yes  No_Disease
# 2    Yes  No_Disease
# 3    Yes  No_Disease
# 4    Yes  No_Disease

# %%
df['exang'] = df['exang'].replace({1: "Yes", 0: "No"})

# %%
df.head()
# Out:
#    age     sex  trestbps  chol    fbs  restecg  thalach exang  oldpeak  thal  \
# 0   63    Male       145   233   True        0      150    No      2.3     1
# 1   37    Male       130   250  False        1      187    No      3.5     2
# 2   41  Female       130   204  False        0      172    No      1.4     2
# 3   56    Male       120   236  False        1      178    No      0.8     2
# 4   57  Female       120   354  False        1      163   Yes      0.6     2
#
#   target      active
# 0    Yes  No_Disease
# 1    Yes  No_Disease
# 2    Yes  No_Disease
# 3    Yes  No_Disease
# 4    Yes  No_Disease

# %%
df['thal'] = df['thal'].replace({1: "fixed_defect", 2: "reversable_defect", 3: "normal"})

# %%
df.head()
# Out:
#    age     sex  trestbps  chol    fbs  restecg  thalach exang  oldpeak  \
# 0   63    Male       145   233   True        0      150    No      2.3
# 1   37    Male       130   250  False        1      187    No      3.5
# 2   41  Female       130   204  False        0      172    No      1.4
# 3   56    Male       120   236  False        1      178    No      0.8
# 4   57  Female       120   354  False        1      163   Yes      0.6
#
#                 thal target      active
# 0       fixed_defect    Yes  No_Disease
# 1  reversable_defect    Yes  No_Disease
# 2  reversable_defect    Yes  No_Disease
# 3  reversable_defect    Yes  No_Disease
# 4  reversable_defect    Yes  No_Disease

# %%
df.hist(bins=30, figsize=(12,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 df.hist(bins=30, figsize=(12,10))
#       2 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_core.py:250, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     145 def hist_frame(
#     146     data: DataFrame,
#     147     column: IndexLabel | None = None,
#    (...)
#     162     **kwargs,
#     163 ):
#     164     """
#     165     Make a histogram of the DataFrame's columns.
#     166
#    (...)
#     248         >>> hist = df.hist(bins=3)
#     249     """
# --> 250     plot_backend = _get_plot_backend(backend)
#     251     return plot_backend.hist_frame(
#     252         data,
#     253         column=column,
#    (...)
#     267         **kwargs,
# ...
